# %%
import gym
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.python.ops.init_ops import VarianceScaling

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
env = gym.make("MsPacman-v0")

# %%
input_size = 7040 
n_actions = env.action_space.n

# %%
mspacman_color = 210 + 164 + 74
def preprocess(obs):
    img = obs[1:176:2, ::2] # crop and downsize
    img = img.sum(axis=2) # to greyscale
    img[img==mspacman_color] = 0 # Improve contrast
    img = (img // 3 - 128).astype(np.int8) # normalize from -128 to 127
    return np.reshape(img.astype(np.float).ravel(), [88, 80, 1])

# %%
class DQN_Agent:

    def __init__(self, 
                 n_actions, 
                 n_features, 
                 learning_rate=0.01,
                 reward_decay=0.99,
                 e_greedy=0.95,
                 update_params_step=300,
                 buffer_size=500,
                 batch_size=32,
                 save_dir = './MsPacman-v0_save_dqn/'):
        
        # set up all parameters
        self.n_actions = n_actions
        self.n_features = n_features
        self.lr = learning_rate
        self.gamma = reward_decay
        self.replace_target_iter = update_params_step
        self.buffer_size = buffer_size
        self.batch_size = batch_size
        self.epsilon = e_greedy
        self.save_dir = save_dir

        # total learning step
        self.learn_step_counter = 0

        # initialize zero memory
        self.memory = np.zeros((self.buffer_size, n_features * 2 + 2))

        # build two networks: target_net, online_net
        self._build_net()
        t_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='target_q_net')
        e_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='eval_q_net')

        with tf.variable_scope('update_all_parameters', reuse=tf.AUTO_REUSE):
            self.target_replace_op = [tf.assign(t, e) for t, e in zip(t_params, e_params)]

        self.sess = tf.Session()
        self.sess.run(tf.global_variables_initializer())
        self.max_q = []

    def _build_net(self):
        """Builds online net and target net"""
        # initialize state, next state, reward, action
        n_features_tensor = [None, 88, 80, 1]
        self.s = tf.placeholder(tf.float32, n_features_tensor, name='s')  
        self.s_ = tf.placeholder(tf.float32, n_features_tensor, name='s_')  
        self.r = tf.placeholder(tf.float32, [None, ], name='r')  
        self.a = tf.placeholder(tf.int32, [None, ], name='a')  

        # initialize weight       
        def lecun_normal(seed=None):
            return VarianceScaling(scale=1., mode='fan_in', distribution='truncated_normal', seed=seed)
        def lecun_uniform(seed=None):
            return VarianceScaling(scale=1., mode='fan_in', distribution='uniform', seed=seed)
        w_initializer = lecun_normal()
        b_initializer = tf.zeros_initializer()

        # build online net 
        with tf.variable_scope('online_net', reuse=tf.AUTO_REUSE):
            conv1 = tf.layers.conv2d(inputs=self.s,
                                     filters=32,
                                     kernel_size=[8, 8],
                                     strides=(4, 4),
                                     padding="same",
                                     activation=tf.nn.relu6,
                                     kernel_initializer=w_initializer)
            conv2 = tf.layers.conv2d(inputs=conv1,
                                     filters=64,
                                     kernel_size=[4, 4],
                                     strides=(2, 2),
                                     padding="same",
                                     activation=tf.nn.relu6,
                                     kernel_initializer=w_initializer)
            conv3 = tf.layers.conv2d(inputs=conv2,
                                     filters=64,
                                     kernel_size=[3, 3],
                                     strides=(1, 1),
                                     padding="same",
                                     activation=tf.nn.relu6,
                                     kernel_initializer=w_initializer)
            flat = tf.contrib.layers.flatten(conv3)
            dense1 = tf.layers.dense(
                            inputs=flat,
                            units=512, 
                            activation=tf.nn.relu,
                            kernel_initializer=w_initializer,
                            bias_initializer=b_initializer)
            self.q_eval = tf.layers.dense(dense1, self.n_actions, kernel_initializer=w_initializer,
                                          bias_initializer=b_initializer, name='online')

        # build target_net
        with tf.variable_scope('target_net', reuse=tf.AUTO_REUSE):
            conv1 = tf.layers.conv2d(inputs=self.s_,
                                     filters=32,
                                     kernel_size=[8, 8],
                                     strides=(4, 4),
                                     padding="same",
                                     activation=tf.nn.relu6,
                                     kernel_initializer=w_initializer)          
            conv2 = tf.layers.conv2d(inputs=conv1,
                                     filters=64,
                                     kernel_size=[4, 4],
                                     strides=(2, 2),
                                     padding="same",
                                     activation=tf.nn.relu6,
                                     kernel_initializer=w_initializer)
            conv3 = tf.layers.conv2d(inputs=conv2,
                                     filters=64,
                                     kernel_size=[3, 3],
                                     strides=(1, 1),
                                     padding="same",
                                     activation=tf.nn.relu6,
                                     kernel_initializer=w_initializer)
            flat = tf.contrib.layers.flatten(conv3)
            dense1 = tf.layers.dense(
                            inputs=flat,
                            units=512, 
                            activation=tf.nn.relu,
                            kernel_initializer=w_initializer,
                            bias_initializer=b_initializer)           
            self.q_next = tf.layers.dense(dense1, self.n_actions, kernel_initializer=w_initializer,
                                          bias_initializer=b_initializer, name='target')

        # target Q value
        with tf.variable_scope('q_target', reuse=tf.AUTO_REUSE):
            q_target = self.r + self.gamma * tf.reduce_max(self.q_next, axis=1, name='Qmax_s_')    
            self.q_target = tf.stop_gradient(q_target)
        # online Q value
        with tf.variable_scope('q_online', reuse=tf.AUTO_REUSE):
            a_indices = tf.stack([tf.range(tf.shape(self.a)[0], dtype=tf.int32), self.a], axis=1)
            self.q_eval_wrt_a = tf.gather_nd(params=self.q_eval, indices=a_indices)   
        # loss function
        with tf.variable_scope('loss', reuse=tf.AUTO_REUSE):
            self.loss = tf.reduce_mean(tf.squared_difference(self.q_target, self.q_eval_wrt_a, name='TD_error'))
        # minimize the difference
        with tf.variable_scope('train', reuse=tf.AUTO_REUSE):
            self._train_op = tf.train.RMSPropOptimizer(self.lr).minimize(self.loss)

    def store_transition(self, s, a, r, s_):
        """Store replay memory"""
        if not hasattr(self, 'memory_counter'):
            self.memory_counter = 0
        transition = np.hstack((s.ravel(), [a, r], s_.ravel()))
        # replace the old memory with new memory
        index = self.memory_counter % self.buffer_size
        self.memory[index, :] = transition
        self.memory_counter += 1

    def choose_action(self, state):
        """Predict action"""
        state = state[np.newaxis, :]
        if np.random.uniform() < self.epsilon:
            # forward feed the state and get q value for every actions
            actions_value = self.sess.run(self.q_eval, feed_dict={self.s: state})
            action = np.argmax(actions_value)
        else:
            action = np.random.randint(0, self.n_actions)
        return action

    def learn(self):
        """Update value parameters using given batch and train the network"""    
        # check to replace target parameters
        if self.learn_step_counter % self.replace_target_iter == 0:
            self.sess.run(self.target_replace_op)

        # sample batch memory when memory is full
        if self.memory_counter > self.buffer_size:
            sample_index = np.random.choice(self.buffer_size, size=self.batch_size)
        else:
            sample_index = np.random.choice(self.memory_counter, size=self.batch_size)
        batch_memory = self.memory[sample_index, :]

        # train the nextwork
        n_features_tensor = [self.batch_size, 88, 80, 1]
        _, loss, q_n = self.sess.run(
            [self._train_op, self.loss, self.q_eval_wrt_a],
            feed_dict={
                self.s: np.reshape(batch_memory[:, :self.n_features], newshape = n_features_tensor),
                self.a: batch_memory[:, self.n_features],
                self.r: batch_memory[:, self.n_features + 1],
                self.s_: np.reshape(batch_memory[:, -self.n_features:], newshape = n_features_tensor),
            })

        # store the loss & q-value for inspection
        self.max_q.append(np.max(q_n))

        # tracking training steps (for parameters update & plotting)
        self.learn_step_counter += 1
    
    def plot_max_q(self):
        """Plot (average) maximum of the Q function versus iteration"""
        self.mean_max_q = [x[0]/x[1] for x in list(zip(np.cumsum(self.max_q), range(1,len(self.max_q)+1)))]
        plt.plot(np.arange(len(self.mean_max_q)), self.mean_max_q)
        plt.ylabel('(average) maximum of the Q function')
        plt.xlabel('iteration')
        plt.show()  
        
    def save_model(self):
        self.ckpts_path = self.save_dir + "dqn.ckpt"
        self.saver = tf.train.Saver()
        self.saver.save(self.sess, self.ckpts_path)

# %%
def train_DQN(episodes):
    """Train dqn network"""

    # keep track of steps for learning resets
    step = 0

    for episode in range(episodes):

        # initial state
        state = env.reset()

        while True:
            
            # choose action based on state
            action = dqn.choose_action(preprocess(state))

            # take action and get next state and reward
            state_, reward, done, info = env.step(action)

            # save observed states to memory
            dqn.store_transition(preprocess(state), action, reward, preprocess(state_))
            
            # only learn when there are enough episodes
            if (step > 1000) and (step % 100 == 0):
                dqn.learn()

            # next state as the current
            state = state_

            # break at end of an episode
            if done:
                if episode % 10 == 0:
                    print('Finsihed episode {}'.format(str(episode)))
                break
            step += 1

    # end of game
    print('Game Over')
    env.close()

# %%
def play_game(episodes):
    """Play game based on trained dqn network"""

    saver = tf.train.Saver()
    saver.restore(dqn.sess, dqn.ckpts_path)

    # keep track of steps for learning resets
    step = 0
    
    rewards = []

    for episode in range(episodes):

        total_reward = 0
        
        # initial state
        state = env.reset()

        while True:
            
            # choose action based on state
            action = dqn.choose_action(preprocess(state))

            # take action and get next state and reward
            state_, reward, done, info = env.step(action)
            
            # Increment reward
            total_reward += reward

            # next state as the current
            state = state_

            # break at end of an episode
            if done:
                rewards.append(total_reward)
                break
            step += 1

    # end of game
    print('Game Over')
    env.close()
    
    """Visualize total rewards in a graph."""
    plt.plot(np.arange(len(rewards)), rewards)
    plt.ylabel('Total Reward')
    plt.xlabel('Episode')
    plt.show()

# %%
dqn = DQN_Agent(n_actions,
                input_size,
                learning_rate=0.005,
                reward_decay=0.99,
                e_greedy=0.9,
                update_params_step=200,
                buffer_size=2000)
    
train_DQN(episodes=5000)
    
dqn.plot_max_q()
dqn.save_model()
    
play_game(episodes=1000)
# Out:
# WARNING:tensorflow:From <ipython-input-5-17dbc28950cd>:68: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-5-17dbc28950cd>:89: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Finsihed episode 0
# Finsihed episode 10
# Finsihed episode 20
# Finsihed episode 30
# Finsihed episode 40
# Finsihed episode 50
# Finsihed episode 60
# Finsihed episode 70
# Finsihed episode 80
# Finsihed episode 90
# Finsihed episode 100
# Finsihed episode 110
# Finsihed episode 120
# Finsihed episode 130
# Finsihed episode 140
# Finsihed episode 150
# Finsihed episode 160
# Finsihed episode 170
# Finsihed episode 180
# Finsihed episode 190
# Finsihed episode 200
# Finsihed episode 210
# Finsihed episode 220
# Finsihed episode 230
# Finsihed episode 240
# Finsihed episode 250
# Finsihed episode 260
# Finsihed episode 270
# Finsihed episode 280
# Finsihed episode 290
# Finsihed episode 300
# Finsihed episode 310
# Finsihed episode 320
# Finsihed episode 330
# Finsihed episode 340
# Finsihed episode 350
# Finsihed episode 360
# Finsihed episode 370
# Finsihed episode 380
# Finsihed episode 390
# Finsihed episode 400
# Finsihed episode 410
# Finsihed episode 420
# Finsihed episode 430
# Finsihed episode 440
# Finsihed episode 450
# Finsihed episode 460
# Finsihed episode 470
# Finsihed episode 480
# Finsihed episode 490
# Finsihed episode 500
# Finsihed episode 510
# Finsihed episode 520
# Finsihed episode 530
# Finsihed episode 540
# Finsihed episode 550
# Finsihed episode 560
# Finsihed episode 570
# Finsihed episode 580
# Finsihed episode 590
# Finsihed episode 600
# Finsihed episode 610
# Finsihed episode 620
# Finsihed episode 630
# Finsihed episode 640
# Finsihed episode 650
# Finsihed episode 660
# Finsihed episode 670
# Finsihed episode 680
# Finsihed episode 690
# Finsihed episode 700
# Finsihed episode 710
# Finsihed episode 720
# Finsihed episode 730
# Finsihed episode 740
# Finsihed episode 750
# Finsihed episode 760
# Finsihed episode 770
# Finsihed episode 780
# Finsihed episode 790
# Finsihed episode 800
# Finsihed episode 810
# Finsihed episode 820
# Finsihed episode 830
# Finsihed episode 840
# Finsihed episode 850
# Finsihed episode 860
# Finsihed episode 870
# Finsihed episode 880
# Finsihed episode 890
# Finsihed episode 900
# Finsihed episode 910
# Finsihed episode 920
# Finsihed episode 930
# Finsihed episode 940
# Finsihed episode 950
# Finsihed episode 960
# Finsihed episode 970
# Finsihed episode 980
# Finsihed episode 990
# Finsihed episode 1000
# Finsihed episode 1010
# Finsihed episode 1020
# Finsihed episode 1030
# Finsihed episode 1040
# Finsihed episode 1050
# Finsihed episode 1060
# Finsihed episode 1070
# Finsihed episode 1080
# Finsihed episode 1090
# Finsihed episode 1100
# Finsihed episode 1110
# Finsihed episode 1120
# Finsihed episode 1130
# Finsihed episode 1140
# Finsihed episode 1150
# Finsihed episode 1160
# Finsihed episode 1170
# Finsihed episode 1180
# Finsihed episode 1190
# Finsihed episode 1200
# Finsihed episode 1210
# Finsihed episode 1220
# Finsihed episode 1230
# Finsihed episode 1240
# Finsihed episode 1250
# Finsihed episode 1260
# Finsihed episode 1270
# Finsihed episode 1280
# Finsihed episode 1290
# Finsihed episode 1300
# Finsihed episode 1310
# Finsihed episode 1320
# Finsihed episode 1330
# Finsihed episode 1340
# Finsihed episode 1350
# Finsihed episode 1360
# Finsihed episode 1370
# Finsihed episode 1380
# Finsihed episode 1390
# Finsihed episode 1400
# Finsihed episode 1410
# Finsihed episode 1420
# Finsihed episode 1430
# Finsihed episode 1440
# Finsihed episode 1450
# Finsihed episode 1460
# Finsihed episode 1470
# Finsihed episode 1480
# Finsihed episode 1490
# Finsihed episode 1500
# Finsihed episode 1510
# Finsihed episode 1520
# Finsihed episode 1530
# Finsihed episode 1540
# Finsihed episode 1550
# Finsihed episode 1560
# Finsihed episode 1570
# Finsihed episode 1580
# Finsihed episode 1590
# Finsihed episode 1600
# Finsihed episode 1610
# Finsihed episode 1620
# Finsihed episode 1630
# Finsihed episode 1640
# Finsihed episode 1650
# Finsihed episode 1660
# Finsihed episode 1670
# Finsihed episode 1680
# Finsihed episode 1690
# Finsihed episode 1700
# Finsihed episode 1710
# Finsihed episode 1720
# Finsihed episode 1730
# Finsihed episode 1740
# Finsihed episode 1750
# Finsihed episode 1760
# Finsihed episode 1770
# Finsihed episode 1780
# Finsihed episode 1790
# Finsihed episode 1800
# Finsihed episode 1810
# Finsihed episode 1820
# Finsihed episode 1830
# Finsihed episode 1840
# Finsihed episode 1850
# Finsihed episode 1860
# Finsihed episode 1870
# Finsihed episode 1880
# Finsihed episode 1890
# Finsihed episode 1900
# Finsihed episode 1910
# Finsihed episode 1920
# Finsihed episode 1930
# Finsihed episode 1940
# Finsihed episode 1950
# Finsihed episode 1960
# Finsihed episode 1970
# Finsihed episode 1980
# Finsihed episode 1990
# Finsihed episode 2000
# Finsihed episode 2010
# Finsihed episode 2020
# Finsihed episode 2030
# Finsihed episode 2040
# Finsihed episode 2050
# Finsihed episode 2060
# Finsihed episode 2070
# Finsihed episode 2080
# Finsihed episode 2090
# Finsihed episode 2100
# Finsihed episode 2110
# Finsihed episode 2120
# Finsihed episode 2130
# Finsihed episode 2140
# Finsihed episode 2150
# Finsihed episode 2160
# Finsihed episode 2170
# Finsihed episode 2180
# Finsihed episode 2190
# Finsihed episode 2200
# Finsihed episode 2210
# Finsihed episode 2220
# Finsihed episode 2230
# Finsihed episode 2240
# Finsihed episode 2250
# Finsihed episode 2260
# Finsihed episode 2270
# Finsihed episode 2280
# Finsihed episode 2290
# Finsihed episode 2300
# Finsihed episode 2310
# Finsihed episode 2320
# Finsihed episode 2330
# Finsihed episode 2340
# Finsihed episode 2350
# Finsihed episode 2360
# Finsihed episode 2370
# Finsihed episode 2380
# Finsihed episode 2390
# Finsihed episode 2400
# Finsihed episode 2410
# Finsihed episode 2420
# Finsihed episode 2430
# Finsihed episode 2440
# Finsihed episode 2450
# Finsihed episode 2460
# Finsihed episode 2470
# Finsihed episode 2480
# Finsihed episode 2490
# Finsihed episode 2500
# Finsihed episode 2510
# Finsihed episode 2520
# Finsihed episode 2530
# Finsihed episode 2540
# Finsihed episode 2550
# Finsihed episode 2560
# Finsihed episode 2570
# Finsihed episode 2580
# Finsihed episode 2590
# Finsihed episode 2600
# Finsihed episode 2610
# Finsihed episode 2620
# Finsihed episode 2630
# Finsihed episode 2640
# Finsihed episode 2650
# Finsihed episode 2660
# Finsihed episode 2670
# Finsihed episode 2680
# Finsihed episode 2690
# Finsihed episode 2700
# Finsihed episode 2710
# Finsihed episode 2720
# Finsihed episode 2730
# Finsihed episode 2740
# Finsihed episode 2750
# Finsihed episode 2760
# Finsihed episode 2770
# Finsihed episode 2780
# Finsihed episode 2790
# Finsihed episode 2800
# Finsihed episode 2810
# Finsihed episode 2820
# Finsihed episode 2830
# Finsihed episode 2840
# Finsihed episode 2850
# Finsihed episode 2860
# Finsihed episode 2870
# Finsihed episode 2880
# Finsihed episode 2890
# Finsihed episode 2900
# Finsihed episode 2910
# Finsihed episode 2920
# Finsihed episode 2930
# Finsihed episode 2940
# Finsihed episode 2950
# Finsihed episode 2960
# Finsihed episode 2970
# Finsihed episode 2980
# Finsihed episode 2990
# Finsihed episode 3000
# Finsihed episode 3010
# Finsihed episode 3020
# Finsihed episode 3030
# Finsihed episode 3040
# Finsihed episode 3050
# Finsihed episode 3060
# Finsihed episode 3070
# Finsihed episode 3080
# Finsihed episode 3090
# Finsihed episode 3100
# Finsihed episode 3110
# Finsihed episode 3120
# Finsihed episode 3130
# Finsihed episode 3140
# Finsihed episode 3150
# Finsihed episode 3160
# Finsihed episode 3170
# Finsihed episode 3180
# Finsihed episode 3190
# Finsihed episode 3200
# Finsihed episode 3210
# Finsihed episode 3220
# Finsihed episode 3230
# Finsihed episode 3240
# Finsihed episode 3250
# Finsihed episode 3260
# Finsihed episode 3270
# Finsihed episode 3280
# Finsihed episode 3290
# Finsihed episode 3300
# Finsihed episode 3310
# Finsihed episode 3320
# Finsihed episode 3330
# Finsihed episode 3340
# Finsihed episode 3350
# Finsihed episode 3360
# Finsihed episode 3370
# Finsihed episode 3380
# Finsihed episode 3390
# Finsihed episode 3400
# Finsihed episode 3410
# Finsihed episode 3420
# Finsihed episode 3430
# Finsihed episode 3440
# Finsihed episode 3450
# Finsihed episode 3460
# Finsihed episode 3470
# Finsihed episode 3480
# Finsihed episode 3490
# Finsihed episode 3500
# Finsihed episode 3510
# Finsihed episode 3520
# Finsihed episode 3530
# Finsihed episode 3540
# Finsihed episode 3550
# Finsihed episode 3560
# Finsihed episode 3570
# Finsihed episode 3580
# Finsihed episode 3590
# Finsihed episode 3600
# Finsihed episode 3610
# Finsihed episode 3620
# Finsihed episode 3630
# Finsihed episode 3640
# Finsihed episode 3650
# Finsihed episode 3660
# Finsihed episode 3670
# Finsihed episode 3680
# Finsihed episode 3690
# Finsihed episode 3700
# Finsihed episode 3710
# Finsihed episode 3720
# Finsihed episode 3730
# Finsihed episode 3740
# Finsihed episode 3750
# Finsihed episode 3760
# Finsihed episode 3770
# Finsihed episode 3780
# Finsihed episode 3790
# Finsihed episode 3800
# Finsihed episode 3810
# Finsihed episode 3820
# Finsihed episode 3830
# Finsihed episode 3840
# Finsihed episode 3850
# Finsihed episode 3860
# Finsihed episode 3870
# Finsihed episode 3880
# Finsihed episode 3890
# Finsihed episode 3900
# Finsihed episode 3910
# Finsihed episode 3920
# Finsihed episode 3930
# Finsihed episode 3940
# Finsihed episode 3950
# Finsihed episode 3960
# Finsihed episode 3970
# Finsihed episode 3980
# Finsihed episode 3990
# Finsihed episode 4000
# Finsihed episode 4010
# Finsihed episode 4020
# Finsihed episode 4030
# Finsihed episode 4040
# Finsihed episode 4050
# Finsihed episode 4060
# Finsihed episode 4070
# Finsihed episode 4080
# Finsihed episode 4090
# Finsihed episode 4100
# Finsihed episode 4110
# Finsihed episode 4120
# Finsihed episode 4130
# Finsihed episode 4140
# Finsihed episode 4150
# Finsihed episode 4160
# Finsihed episode 4170
# Finsihed episode 4180
# Finsihed episode 4190
# Finsihed episode 4200
# Finsihed episode 4210
# Finsihed episode 4220
# Finsihed episode 4230
# Finsihed episode 4240
# Finsihed episode 4250
# Finsihed episode 4260
# Finsihed episode 4270
# Finsihed episode 4280
# Finsihed episode 4290
# Finsihed episode 4300
# Finsihed episode 4310
# Finsihed episode 4320
# Finsihed episode 4330
# Finsihed episode 4340
# Finsihed episode 4350
# Finsihed episode 4360
# Finsihed episode 4370
# Finsihed episode 4380
# Finsihed episode 4390
# Finsihed episode 4400
# Finsihed episode 4410
# Finsihed episode 4420
# Finsihed episode 4430
# Finsihed episode 4440
# Finsihed episode 4450
# Finsihed episode 4460
# Finsihed episode 4470
# Finsihed episode 4480
# Finsihed episode 4490
# Finsihed episode 4500
# Finsihed episode 4510
# Finsihed episode 4520
# Finsihed episode 4530
# Finsihed episode 4540
# Finsihed episode 4550
# Finsihed episode 4560
# Finsihed episode 4570
# Finsihed episode 4580
# Finsihed episode 4590
# Finsihed episode 4600
# Finsihed episode 4610
# Finsihed episode 4620
# Finsihed episode 4630
# Finsihed episode 4640
# Finsihed episode 4650
# Finsihed episode 4660
# Finsihed episode 4670
# Finsihed episode 4680
# Finsihed episode 4690
# Finsihed episode 4700
# Finsihed episode 4710
# Finsihed episode 4720
# Finsihed episode 4730
# Finsihed episode 4740
# Finsihed episode 4750
# Finsihed episode 4760
# Finsihed episode 4770
# Finsihed episode 4780
# Finsihed episode 4790
# Finsihed episode 4800
# Finsihed episode 4810
# Finsihed episode 4820
# Finsihed episode 4830
# Finsihed episode 4840
# Finsihed episode 4850
# Finsihed episode 4860
# Finsihed episode 4870
# Finsihed episode 4880
# Finsihed episode 4890
# Finsihed episode 4900
# Finsihed episode 4910
# Finsihed episode 4920
# Finsihed episode 4930
# Finsihed episode 4940
# Finsihed episode 4950
# Finsihed episode 4960
# Finsihed episode 4970
# Finsihed episode 4980
# Finsihed episode 4990
# Game Over
# INFO:tensorflow:Restoring parameters from ./MsPacman-v0_save_dqn/dqn.ckpt
# Game Over
